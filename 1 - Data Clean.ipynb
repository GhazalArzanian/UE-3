# %%
import pandas as pd

# %%
df = pd.read_csv("data/raw_global_youtube_statistics.csv", encoding="ISO-8859-1")

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports               Natan por Aï¿     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US          Games  ...                           NaN
# 2             US  Entertainment  ...                     8000000.0
# 3             US      Education  ...                     1000000.0
# 4             IN  Entertainment  ...                     1000000.0
# ..           ...            ...  ...                           ...
# 990           BR  Entertainment  ...                      700000.0
# 991           IN          Games  ...                      300000.0
# 992           GB          Games  ...                        1000.0
# 993           SE          Games  ...                      100000.0
# 994           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0          2006.0            Mar          13.0
# 1          2006.0            Mar           5.0
# 2          2012.0            Feb          20.0
# 3          2006.0            Sep           1.0
# 4          2006.0            Sep          20.0
# ..            ...            ...           ...
# 990        2017.0            Feb          12.0
# 991        2018.0            Sep          14.0
# 992        2006.0            Sep          11.0
# 993        2012.0            May           9.0
# 994        2017.0            Aug           1.0
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                       28.1  1.366418e+09               5.36
# 1                                       88.2  3.282395e+08              14.70
# 2                                       88.2  3.282395e+08              14.70
# 3                                       88.2  3.282395e+08              14.70
# 4                                       28.1  1.366418e+09               5.36
# ..                                       ...           ...                ...
# 990                                     51.3  2.125594e+08              12.08
# 991                                     28.1  1.366418e+09               5.36
# 992                                     60.0  6.683440e+07               3.85
# 993                                     67.0  1.028545e+07               6.48
# 994                                     28.1  1.366418e+09               5.36
#
#      Urban_population   Latitude  Longitude
# 0         471031528.0  20.593684  78.962880
# 1         270663028.0  37.090240 -95.712891
# 2         270663028.0  37.090240 -95.712891
# 3         270663028.0  37.090240 -95.712891
# 4         471031528.0  20.593684  78.962880
# ..                ...        ...        ...
# 990       183241641.0 -14.235004 -51.925280
# 991       471031528.0  20.593684  78.962880
# 992        55908316.0  55.378051  -3.435973
# 993         9021165.0  60.128161  18.643501
# 994       471031528.0  20.593684  78.962880
#
# [995 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
del df['Title']
del df['Abbreviation']

# %%
cols=['rank', 'Youtuber', 'subscribers', 'video views', 'category',
       'uploads', 'Country', 
       'video_views_rank', 'country_rank',
       'highest_monthly_earnings',
       'created_year', 
       'Gross tertiary education enrollment (%)',
       'Unemployment rate']

# %%
df_col= df[cols]

# %%
df_col
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category  uploads         Country  video_views_rank  \
# 0               Music    20082           India               1.0
# 1    Film & Animation        1   United States         4055159.0
# 2       Entertainment      741   United States              48.0
# 3           Education      966   United States               2.0
# 4               Shows   116536           India               3.0
# ..                ...      ...             ...               ...
# 990            Sports     1200          Brazil             525.0
# 991    People & Blogs     1500           India            6141.0
# 992               NaN     2452  United Kingdom          129005.0
# 993            Gaming       39          Sweden           35112.0
# 994            Comedy       62           India            4568.0
#
#      country_rank  highest_monthly_earnings  created_year  \
# 0             1.0                9000000.00        2006.0
# 1          7670.0                      0.05        2006.0
# 2             1.0                5400000.00        2012.0
# 3             2.0                7900000.00        2006.0
# 4             2.0                7300000.00        2006.0
# ..            ...                       ...           ...
# 990          55.0                2200000.00        2017.0
# 991         125.0                 258900.00        2018.0
# 992         867.0                    268.00        2006.0
# 993           4.0                  15500.00        2012.0
# 994         125.0                  96000.00        2017.0
#
#      Gross tertiary education enrollment (%)  Unemployment rate
# 0                                       28.1               5.36
# 1                                       88.2              14.70
# 2                                       88.2              14.70
# 3                                       88.2              14.70
# 4                                       28.1               5.36
# ..                                       ...                ...
# 990                                     51.3              12.08
# 991                                     28.1               5.36
# 992                                     60.0               3.85
# 993                                     67.0               6.48
# 994                                     28.1               5.36
#
# [995 rows x 13 columns]

# %%
df_col.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# uploads                                      0
# Country                                    122
# video_views_rank                             1
# country_rank                               116
# highest_monthly_earnings                     0
# created_year                                 5
# Gross tertiary education enrollment (%)    123
# Unemployment rate                          123
# dtype: int64

# %%
df_cleaned1=df_col.dropna(subset=["Country", "category", "country_rank", "created_year", "Unemployment rate"])

# %%
df_cleaned1
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category  uploads        Country  video_views_rank  country_rank  \
# 0               Music    20082          India               1.0           1.0
# 1    Film & Animation        1  United States         4055159.0        7670.0
# 2       Entertainment      741  United States              48.0           1.0
# 3           Education      966  United States               2.0           2.0
# 4               Shows   116536          India               3.0           2.0
# ..                ...      ...            ...               ...           ...
# 989             Music       99  United States             833.0         175.0
# 990            Sports     1200         Brazil             525.0          55.0
# 991    People & Blogs     1500          India            6141.0         125.0
# 993            Gaming       39         Sweden           35112.0           4.0
# 994            Comedy       62          India            4568.0         125.0
#
#      highest_monthly_earnings  created_year  \
# 0                  9000000.00        2006.0
# 1                        0.05        2006.0
# 2                  5400000.00        2012.0
# 3                  7900000.00        2006.0
# 4                  7300000.00        2006.0
# ..                        ...           ...
# 989                 197600.00        2012.0
# 990                2200000.00        2017.0
# 991                 258900.00        2018.0
# 993                  15500.00        2012.0
# 994                  96000.00        2017.0
#
#      Gross tertiary education enrollment (%)  Unemployment rate
# 0                                       28.1               5.36
# 1                                       88.2              14.70
# 2                                       88.2              14.70
# 3                                       88.2              14.70
# 4                                       28.1               5.36
# ..                                       ...                ...
# 989                                     88.2              14.70
# 990                                     51.3              12.08
# 991                                     28.1               5.36
# 993                                     67.0               6.48
# 994                                     28.1               5.36
#
# [830 rows x 13 columns]

# %%
df_cleaned1["category"].value_counts()
# Out:
# category
# Entertainment            213
# Music                    180
# People & Blogs           103
# Gaming                    80
# Comedy                    67
# Education                 42
# Film & Animation          36
# Howto & Style             33
# News & Politics           26
# Science & Technology      15
# Shows                     12
# Sports                    11
# Pets & Animals             3
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
df_cleaned1.to_csv('data/cleaned_global_youtube_statistics.csv', index=False)

# %%
df_cleaned1.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'uploads',
#        'Country', 'video_views_rank', 'country_rank',
#        'highest_monthly_earnings', 'created_year',
#        'Gross tertiary education enrollment (%)', 'Unemployment rate'],
#       dtype='object')
